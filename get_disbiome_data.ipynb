# %%
import pandas as pd

# %%
df = pd.read_json("https://disbiome.ugent.be:8080/experiment")

# %%
df
# Out:
#        experiment_id  methodological_detail_id qualitative_outcome  \
# 0                  1                       NaN            Elevated
# 1                  2                       NaN            Elevated
# 2                  3                       NaN            Elevated
# 3                  4                     207.0            Elevated
# 4                  5                     207.0            Elevated
# ...              ...                       ...                 ...
# 10929          11408                     653.0            Elevated
# 10930          11409                     653.0            Elevated
# 10931          11410                     653.0            Elevated
# 10932          11411                     653.0            Elevated
# 10933          11412                     653.0             Reduced
#
#        disease_id    meddra_level   meddra_id  location_id  \
# 0               1  preferred_term  10080683.0         10.0
# ...

# %%
df.to_csv("disbiome.csv")
