# %%
import pandas as pd

# %%
gad = pd.read_csv("gad.csv")

# %%
gad
# Out:
#        gad_id association                      phenotype    disease_class  \
# 0      122182         NaN      1,3-butadiene sensitivity  PHARMACOGENOMIC
# 1      122187         NaN         1,3-butadiene toxicity  PHARMACOGENOMIC
# 2      120138           Y    11beta-hydroxylase activity  PHARMACOGENOMIC
# 3      120200         NaN    11beta-hydroxylase activity  PHARMACOGENOMIC
# 4      145983         NaN  11beta-hydroxylase efficiency  NORMALVARIATION
# ...       ...         ...                            ...              ...
# 39905  155040           P                            NaN  NORMALVARIATION
# 39906  155184         NaN                            NaN            OTHER
# 39907  155212           P                            NaN  NORMALVARIATION
# 39908  155213           P                            NaN  NORMALVARIATION
# 39909  155282           P                            NaN  NORMALVARIATION
#
#       chromosome chromosome_band  dna_start    dna_end     gene  \
# ...

# %%
gad["phenotype"] = gad["phenotype"].str.lower()

# %%
gad.to_csv("gad.csv")
