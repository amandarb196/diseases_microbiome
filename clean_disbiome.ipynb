# %%
import pandas as pd

# %%
disbiome = pd.read_csv("disbiome_og.csv")

# %%
disbiome
# Out:
#        Unnamed: 0  experiment_id  methodological_detail_id  \
# 0             168            169                       NaN
# 1             167            168                       NaN
# 2             166            167                       NaN
# 3             165            166                       NaN
# 4             164            165                       NaN
# ...           ...            ...                       ...
# 10929        8033           8471                       NaN
# 10930        8034           8472                       NaN
# 10931        8035           8473                       NaN
# 10932        8036           8474                       NaN
# 10933        1354           1411                       NaN
#
#       qualitative_outcome  disease_id    meddra_level   meddra_id  \
# 0                 Reduced          14  preferred_term  10011762.0
# 1                 Reduced          14  preferred_term  10011762.0
# ...

# %%
disbiome["disease_name"] = disbiome["disease_name"].str.lower()

# %%
disbiome.to_csv("disbiome2.csv")
